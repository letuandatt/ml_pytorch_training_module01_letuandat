# %% [markdown]
# # Exercise 2: Tensor Operations
# **PyTorch Fundamentals - Module 1**
#
# This exercise covers:
# - Basic arithmetic operations
# - Matrix operations
# - Reduction operations
# - Comparison operations
#
# PyTorch 2.0 Note: All operations in this file are compatible with PyTorch 2.0.
# The @ operator for matrix multiplication is recommended for both PyTorch 1.x and 2.0.

# %%
import torch

# %%
torch.manual_seed(42)

# %% [markdown]
# ## Part 1: Basic Arithmetic Operations

# %% [markdown]
# **Create test tensors**

# %%
x = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
y = torch.tensor([5, 6, 7, 8], dtype=torch.float32)

# %%
x
# Out:
# tensor([1., 2., 3., 4.])

# %%
y
# Out:
# tensor([5., 6., 7., 8.])

# %% [markdown]
# **Addition**

# %%
add_result = x + y
print(f"\nAddition (x + y):\n\t{add_result}")
# Out:
# Addition (x + y):
# 	tensor([ 6.,  8., 10., 12.])

# %% [markdown]
# **Subtraction**

# %%
sub_result = x - y
print(f"Subtraction (x - y):\n\t{sub_result}")
# Out:
# Subtraction (x - y):
# 	tensor([-4., -4., -4., -4.])

# %% [markdown]
# **Element-wise multiplication**

# %%
mul_result = x * y
print(f"Multiplication (x * y):\n\t{mul_result}")
# Out:
# Multiplication (x * y):
# 	tensor([ 5., 12., 21., 32.])

# %% [markdown]
# **Element-wise division**

# %%
div_result = x / y
print(f"Division (x / y):\n\t{div_result}")
# Out:
# Division (x / y):
# 	tensor([0.2000, 0.3333, 0.4286, 0.5000])

# %% [markdown]
# **Power**

# %%
pow_result = x ** 2
print(f"Power (x^2):\n\t{pow_result}")
# Out:
# Power (x^2):
# 	tensor([ 1.,  4.,  9., 16.])

# %% [markdown]
# ## Part 2: Matrix Operations

# %% [markdown]
# **Create matrices**

# %%
A = torch.randn(3, 4)
B = torch.randn(4, 5)

# %%
print(A)
# Out:
# tensor([[ 0.3367,  0.1288,  0.2345,  0.2303],
#         [-1.1229, -0.1863,  2.2082, -0.6380],
#         [ 0.4617,  0.2674,  0.5349,  0.8094]])

# %%
print(B)
# Out:
# tensor([[ 0.3559, -0.6866, -0.4934,  0.2415,  1.3123],
#         [ 0.6872, -1.0892, -0.3553, -0.9138, -0.6581],
#         [ 0.0780,  0.5258,  1.1790, -0.4345, -1.3864],
#         [-1.2862, -1.4032,  0.0360, -0.0635,  0.6756]])

# %%
print(f"Matrix A shape: {A.shape}")
print(f"Matrix B shape: {B.shape}")
# Out:
# Matrix A shape: torch.Size([3, 4])
# Matrix B shape: torch.Size([4, 5])

# %% [markdown]
# **Matrix multiplication**

# %%
matmul_result = A @ B
print(f"\nMatrix multiplication A @ B shape: {matmul_result.shape}")
# Out:
# Matrix multiplication A @ B shape: torch.Size([3, 5])

# %%
print(matmul_result)
# Out:
# tensor([[-0.0696, -0.5714,  0.0728, -0.1529,  0.1876],
#         [ 0.4653,  3.0303,  3.2006, -1.0197, -4.8433],
#         [-0.6513, -1.4626,  0.3370, -0.4166,  0.2351]])

# %% [markdown]
# **Transpose**

# %%
A_T = A.T
print(f"Transpose of A shape: {A_T.shape}")
# Out:
# Transpose of A shape: torch.Size([4, 3])

# %%
print(A_T)
# Out:
# tensor([[ 0.3367, -1.1229,  0.4617],
#         [ 0.1288, -0.1863,  0.2674],
#         [ 0.2345,  2.2082,  0.5349],
#         [ 0.2303, -0.6380,  0.8094]])

# %% [markdown]
# **Element-wise min/max**

# %%
min_val = torch.min(A)
max_val = torch.max(A)

# %%
print(f"\nMin value in A: {min_val:.4f}")
print(f"Max value in A: {max_val:.4f}")
# Out:
# Min value in A: -1.1229
# Max value in A: 2.2082

# %% [markdown]
# ## Part 3: Reduction Operations

# %% [markdown]
# **Create a 2D tensor**

# %%
tensor = torch.randn(3, 4)
print(f"Tensor:\n{tensor}")
# Out:
# Tensor:
# tensor([[-0.0085,  0.7291,  0.1331,  0.8640],
#         [-1.0157, -0.8887,  0.1498, -0.2089],
#         [-0.3870,  0.9912,  0.4679, -0.2049]])

# %% [markdown]
# **Sum all elements**

# %%
sum_all = torch.sum(tensor)
print(f"\nSum of all elements: {sum_all:.4f}")
# Out:
# Sum of all elements: 0.6213

# %% [markdown]
# **Sum along rows (dim=0)**

# %%
sum_rows = torch.sum(tensor, dim=0)
print(f"Sum along rows: {sum_rows}")
# Out:
# Sum along rows: tensor([-1.4112,  0.8315,  0.7508,  0.4502])

# %% [markdown]
# **Sum along columns (dim=1)**

# %%
sum_cols = torch.sum(tensor, dim=1)
print(f"Sum along columns: {sum_cols}")
# Out:
# Sum along columns: tensor([ 1.7177, -1.9635,  0.8672])

# %% [markdown]
# **Mean**

# %%
mean_all = torch.mean(tensor)
print(f"\nMean of all elements: {mean_all:.4f}")
print(mean_all == sum_all / tensor.numel())
# Out:
# Mean of all elements: 0.0518
# tensor(True)

# %% [markdown]
# **Standard deviation**

# %%
std_all = torch.std(tensor)
print(f"Standard deviation: {std_all:.4f}")
# Out:
# Standard deviation: 0.6428

# %% [markdown]
# ## Part 4: Comparison Operations

# %%
x = torch.tensor([1, 2, 3, 4, 5])
y = torch.tensor([2, 2, 4, 4, 6])

print(f"x: {x}")
print(f"y: {y}")
# Out:
# x: tensor([1, 2, 3, 4, 5])
# y: tensor([2, 2, 4, 4, 6])

# %% [markdown]
# **Element-wise comparison**

# %%
eq_result = x == y
print(f"\nEqual (x == y): {eq_result}")
# Out:
# Equal (x == y): tensor([False,  True, False,  True, False])

# %%
gt_result = x > y
print(f"Greater than (x > y): {gt_result}")
# Out:
# Greater than (x > y): tensor([False, False, False, False, False])

# %%
lt_result = x < y
print(f"Less than (x < y): {lt_result}")
# Out:
# Less than (x < y): tensor([ True, False,  True, False,  True])

# %% [markdown]
# **Clamp values**

# %%
clamped = torch.clamp(x, min=2, max=4)
print(f"\nClamp x to [2, 4]: {clamped}")
# Out:
# Clamp x to [2, 4]: tensor([2, 2, 3, 4, 4])

# %%
clamped_y = torch.clamp(y, min=5, max=9)
print(f"Clamp y to [5, 9]: {clamped_y}")
# Out:
# Clamp y to [5, 9]: tensor([5, 5, 5, 5, 6])

# %% [markdown]
# ## Part 5: Broadcasting

# %% [markdown]
# **Create tensors with different shapes**

# %%
x = torch.randn(3, 1)
y = torch.randn(1, 4)

print(f"x shape: {x.shape}")
print(f"y shape: {y.shape}")
# Out:
# x shape: torch.Size([3, 1])
# y shape: torch.Size([1, 4])

# %%
print(x, y, sep="\n\n")
# Out:
# tensor([[-0.7409],
#         [ 0.3618],
#         [ 1.9199]])
#
# tensor([[-0.2254, -0.3417,  0.3040, -0.6890]])

# %% [markdown]
# **Broadcast addition**

# %%
result = x + y
print(f"\nBroadcast result shape: {result.shape}")
print(f"Result:\n{result}")
# Out:
# Broadcast result shape: torch.Size([3, 4])
# Result:
# tensor([[-0.9663, -1.0826, -0.4369, -1.4299],
#         [ 0.1365,  0.0201,  0.6659, -0.3272],
#         [ 1.6945,  1.5782,  2.2239,  1.2309]])

# %% [markdown]
# ## Exercise

# %% [markdown]
# **Exercise 1: Given two matrices A (4x3) and B (3x5), compute C = A @ B**

# %%
A = torch.randn(4, 3)
B = torch.randn(3, 5)

# %%
print(A, B, sep="\n\n")
# Out:
# tensor([[-1.1267, -0.2858, -1.0935],
#         [ 1.1351,  0.7592, -3.5945],
#         [ 0.0192,  0.1052,  0.9603],
#         [-0.5672, -0.5706,  1.5980]])
#
# tensor([[ 0.1115, -0.0392,  1.4112, -0.6556,  0.8576],
#         [-1.6270, -1.3951, -0.2387, -0.5050, -2.4752],
#         [-0.9316, -0.1335,  0.3415, -0.0716, -0.0909]])

# %%
print(f"Matrix multiplication A @ B shape: {(A @ B).shape}")
# Out:
# Matrix multiplication A @ B shape: torch.Size([4, 5])

# %%
print(f"Matrix multiplication A @ B:\n{A @ B}")
# Out:
# Matrix multiplication A @ B:
# tensor([[ 1.3580,  0.5888, -1.8952,  0.9613, -0.1596],
#         [ 2.2399, -0.6239,  0.1931, -0.8703, -0.5791],
#         [-1.0636, -0.2757,  0.3299, -0.1344, -0.3312],
#         [-0.6235,  0.6050, -0.1184,  0.5456,  0.7808]])

# %% [markdown]
# **Exercise 2: Normalize a tensor to have zero mean and unit variance**

# %%
tensor = torch.randn(100, 10)

# %%
print(tensor)
# Out:
# tensor([[-1.2389e+00, -1.1812e+00, -1.0318e-01,  1.6807e+00, -2.9093e-01,
#          -1.9038e-01, -4.3973e-01,  8.9013e-01,  4.5068e-01,  8.2047e-01],
#         [-7.4839e-01,  6.8000e-01, -1.4508e-01, -1.0368e-02, -4.8061e-01,
#          -1.6556e-02, -6.0004e-01, -5.9534e-01, -4.3246e-01, -7.1259e-01],
#         [-7.0029e-01,  1.2313e+00,  9.1771e-01, -8.5286e-02, -1.7139e+00,
#           3.8805e-01, -4.6878e-02, -6.6701e-01,  2.8772e-01, -8.5422e-01],
#         [ 7.5001e-01, -2.1544e+00, -1.8525e-01, -3.4355e-01, -9.8278e-01,
#           1.4724e+00,  5.1843e-01,  1.1344e+00, -1.1047e+00,  3.9971e-01],
#         [ 6.0474e-01,  9.9502e-02,  2.1674e-01, -7.4463e-01, -1.8894e+00,
#           8.2298e-01, -1.4357e-02,  1.0571e+00, -1.0370e+00, -2.9757e-01],
#         [-8.5172e-01,  2.8918e-01, -8.9324e-01,  1.8647e+00,  5.0715e-02,
#           1.9659e-02, -1.2775e-01,  3.5776e-01, -1.1238e+00,  4.6559e-01],
#         [-3.0510e+00,  8.5078e-01,  5.7983e-01,  2.4295e-01, -1.3800e+00,
#          -3.6408e-01, -1.9835e-01,  5.5466e-01,  2.6536e-01, -2.7042e-01],
#         [ 1.2101e+00, -8.5611e-01,  8.9708e-01,  1.0964e+00,  3.7794e-03,
#           4.1841e-01,  7.4512e-01,  1.9408e-02, -4.4265e-01,  1.2388e+00],
#         [ 1.3957e+00, -8.7656e-03,  4.5100e-02,  2.1805e-01,  2.1767e+00,
#           2.1929e+00, -6.4339e-01,  1.6815e+00, -8.9847e-01, -8.5000e-01],
#         [-9.5510e-01,  3.3139e-02,  4.1757e-01,  1.9636e+00, -9.6477e-01,
#           7.5937e-01, -3.1804e-01,  5.6581e-01,  2.5520e-01, -1.1028e+00],
#         [ 8.2387e-01,  3.5750e-03, -1.7264e+00,  2.3051e-01,  3.8822e-01,
#          -5.2509e-01, -1.2151e-01,  4.1562e-01,  1.0095e+00,  6.8181e-01],
#         [-7.3001e-01, -8.3037e-01, -1.5722e+00,  6.4518e-01,  1.7553e-01,
#           2.9882e-01, -6.0177e-01,  1.1091e+00, -2.6972e-01, -4.3794e-01],
#         [-5.4044e-01,  4.8842e-01,  1.5679e-01,  1.9906e-01,  6.8680e-01,
#          -4.2603e-01, -7.5601e-01,  1.7112e-01, -1.1433e+00, -6.3480e-01],
#         [ 1.1803e+00,  3.7527e-01,  1.6406e-01, -5.8201e-01, -6.0776e-01,
#          -2.0456e-01,  7.3480e-01,  1.4139e+00, -6.9161e-02, -2.5020e-01],
#         [-6.3193e-01, -1.0362e-01,  9.8325e-01, -2.1118e-01, -3.8377e-01,
#          -7.6813e-01, -1.0034e+00, -9.6553e-01,  2.1109e-01, -1.4139e+00],
#         [ 8.9205e-01, -3.0398e-01, -4.3411e-01,  2.9294e-01,  1.1548e-01,
#          -1.7881e-01, -9.4050e-02, -6.3300e-01,  2.0147e+00,  6.4448e-01],
#         [-1.0493e+00,  1.0829e+00, -9.0567e-01, -1.0401e+00,  3.7873e-01,
#          -1.7898e-01, -6.7519e-01, -7.5165e-01, -1.2752e+00, -9.8071e-01],
#         [ 7.7802e-01, -2.3794e-01, -7.6523e-01, -8.6415e-01, -2.8838e-01,
#          -1.0859e+00,  5.7629e-02,  3.5209e-01,  1.0967e+00, -9.8828e-01],
#         [ 1.9996e+00, -1.2998e+00, -9.0242e-01, -2.4198e+00,  1.2205e+00,
#          -1.5345e-01, -5.1195e-01,  1.1924e-01,  1.4289e+00,  2.0870e+00],
#         [ 1.0071e+00, -1.2568e-01, -2.9633e-01,  6.2816e-01,  7.9721e-01,
#           6.9573e-01, -1.8520e-01,  1.9909e-01,  2.0384e-01, -7.2481e-01],
#         [-8.8241e-02, -1.1839e+00, -2.3502e-01,  6.6807e-01, -7.2055e-01,
#           9.8160e-01,  1.7614e-01,  1.0092e-01,  5.1833e-01,  1.0639e-01],
#         [-7.0810e-02,  1.8684e-01, -1.1356e+00, -6.1216e-01,  4.7325e-01,
#           2.2349e-01,  4.5917e-01,  3.6398e-01,  2.4808e-01, -5.7142e-01],
#         [-1.8830e+00,  1.6258e+00, -7.0380e-01,  5.5813e-01,  4.2073e-01,
#           1.2928e+00, -6.2042e-02, -7.4470e-02,  1.8145e+00,  4.1260e-01],
#         [-5.3844e-01, -6.6991e-01,  1.3212e-01, -4.5546e-01,  7.1002e-01,
#          -1.4319e+00,  1.3608e+00,  6.6452e-01, -1.9415e-01, -1.3719e+00],
#         [ 1.7688e+00,  1.2300e+00,  2.9569e-01,  8.4007e-01, -1.2442e+00,
#          -7.0978e-01,  1.1574e+00,  4.0682e-02,  1.1155e+00, -1.8691e+00],
#         [ 1.0895e+00, -6.6232e-01, -4.4681e-01, -6.8173e-01, -3.4068e-01,
#           2.2806e-01, -9.9476e-01, -1.3262e+00, -1.4499e+00,  1.4251e-01],
#         [ 3.2056e-01, -5.8523e-01,  4.0609e-01,  2.5730e-01,  3.2189e-01,
#           1.3224e-01,  3.4671e-01, -8.1594e-02, -1.4703e+00, -3.4158e-01],
#         [ 1.2260e+00,  1.8914e+00, -2.0125e+00, -5.1626e-01,  1.7348e+00,
#           3.2030e-02,  9.7269e-01,  1.0880e+00, -1.1082e+00,  2.1468e+00],
#         [-7.2176e-01,  1.9135e+00, -3.2725e-01,  4.8204e-01, -1.8594e+00,
#           1.4130e-01,  1.6815e+00,  9.1419e-01, -5.4068e-01, -8.2993e-01],
#         [ 1.9964e-01, -1.9339e-01, -1.2196e+00,  1.0412e+00, -1.0632e-01,
#           7.3362e-02,  5.9396e-01,  1.3427e+00, -5.1559e-01,  3.2028e-01],
#         [ 1.5523e+00,  1.3523e+00,  1.1633e+00, -5.6020e-01, -1.5106e-01,
#          -5.3372e-01,  5.6202e-01, -2.7735e+00,  1.1568e+00, -2.4877e-01],
#         [-1.0994e-01, -4.2326e-01, -1.8522e+00, -1.1897e+00, -6.5820e-01,
#           3.9524e-01, -6.9847e-01,  8.1949e-01,  8.8264e-01,  9.7220e-01],
#         [-1.2662e-01, -4.5185e-02,  1.8064e-01,  5.3500e-01, -1.0952e+00,
#           2.3320e-01,  5.8438e-01, -2.2863e+00,  2.1618e-01, -6.1230e-01],
#         [-2.5462e-01,  9.9259e-01,  4.5372e-01, -9.3296e-01, -5.6427e-02,
#           9.5682e-01,  1.9666e+00,  4.4047e-01, -5.9434e-01,  7.2064e-01],
#         [-1.0878e+00, -1.9153e-01,  8.1608e-01, -8.2334e-01, -3.1327e-01,
#          -1.8329e-01, -1.7837e-01,  2.0791e+00,  1.4888e-01,  3.1910e+00],
#         [-9.3343e-01, -1.2067e-01, -8.5683e-01, -1.4692e+00,  9.2607e-01,
#          -5.5944e-01,  2.2181e+00,  4.0002e-01,  4.2209e-01, -1.2680e+00],
#         [-1.0606e+00,  1.0454e+00,  1.1547e+00,  3.2125e-01,  1.3645e-01,
#          -1.7697e+00, -4.9656e-01,  1.6126e+00,  3.4458e-02,  5.0891e-01],
#         [ 6.4701e-01, -5.0199e-01, -1.4353e-01, -1.2236e+00, -1.5852e+00,
#           1.1070e+00,  2.5731e+00, -7.0517e-01, -1.1590e+00, -2.7696e-01],
#         [ 1.1326e+00, -9.6168e-01, -1.3317e-02, -3.0807e-01, -1.3066e+00,
#           1.1060e+00,  9.2155e-01, -1.3966e+00, -8.8801e-01, -2.2111e+00],
#         [ 1.6702e+00,  5.9547e-02,  4.6923e-05,  5.6878e-01,  8.2380e-01,
#          -9.7693e-01, -7.5708e-01,  6.2370e-01, -2.6205e-01,  5.0705e-01],
#         [ 5.8776e-01, -7.6670e-01,  1.4354e-01, -9.0786e-01,  2.1903e+00,
#           2.5667e-01,  4.6254e-01, -1.1410e+00, -5.8378e-01, -7.0808e-01],
#         [-1.1738e+00, -6.3204e-01, -1.0963e+00, -7.8473e-01, -5.7523e-01,
#           5.1386e-01, -4.2104e-01, -6.6369e-01,  1.4599e+00, -1.9324e+00],
#         [ 2.9507e-01,  1.9531e+00,  6.2262e-02, -1.1079e+00, -5.1826e-02,
#           4.1152e-01, -2.9665e-01, -2.6533e-01, -7.9975e-01,  1.0419e+00],
#         [ 1.3011e+00, -4.0847e-01,  8.6756e-01,  1.5684e+00,  1.8340e-01,
#          -5.8144e-02,  3.2200e-01,  4.6689e-01,  1.4413e-02, -1.1833e+00],
#         [ 1.9590e+00, -4.6830e-01,  1.3324e+00, -9.3080e-02, -1.1492e+00,
#           3.9312e-01, -3.8927e-01,  5.2934e-01, -8.9302e-02, -2.8385e+00],
#         [ 4.5555e-01, -2.7461e-01,  9.4947e-01, -8.7208e-01,  8.0297e-01,
#           2.7744e-01,  1.6848e+00,  4.4387e-01, -6.8468e-01, -7.6889e-01],
#         [ 1.9105e+00, -9.2819e-01,  7.4256e-01,  2.0378e+00, -1.2777e+00,
#           4.2116e-01, -7.2888e-01, -9.4498e-01,  6.4846e-01, -3.4857e-01],
#         [ 4.4557e-01,  1.6405e-02, -1.3468e+00,  8.5813e-01, -1.7792e-01,
#           8.0022e-01,  1.2354e+00,  5.4584e-01,  3.9610e-01,  1.7752e-01],
#         [ 9.9852e-01,  3.6746e-02,  2.2978e-01, -1.9846e+00, -1.2512e+00,
#           6.2193e-01,  6.5814e-01,  1.5087e+00,  5.7260e-01,  3.8635e-01],
#         [ 2.7224e-01,  4.6132e-01,  1.3580e-01,  5.1680e-01, -9.4219e-01,
#           1.3477e+00,  1.7520e+00, -3.7439e-01,  9.5080e-01,  1.3072e+00],
#         [-7.5126e-01,  5.1398e-03,  5.7868e-01, -1.0997e+00,  1.9344e+00,
#          -4.4565e-01, -4.7476e-01, -3.0262e-01, -2.9394e-01,  2.5355e+00],
#         [-5.1319e-02, -2.6267e-01, -4.2282e-01, -7.3227e-01, -3.9794e-01,
#          -4.9837e-03, -2.1660e+00,  5.3050e-01, -4.5320e-01,  1.2440e+00],
#         [ 1.8615e+00, -1.1588e-01, -6.8225e-01,  4.2130e-01, -1.3226e+00,
#           1.2115e+00, -3.1363e-01,  1.3522e-01, -1.2083e+00,  3.1685e+00],
#         [ 2.2975e+00, -1.4130e-01, -1.9954e+00,  3.5315e-02, -6.1478e-01,
#           1.4755e+00, -5.2302e-01, -1.1935e+00, -1.0896e+00,  1.5079e+00],
#         [ 2.5914e-01,  2.9248e+00, -1.2941e+00,  1.4419e-01,  1.5032e+00,
#           8.5995e-01,  5.6636e-01, -1.3874e+00, -3.3615e-01,  2.1690e-01],
#         [-7.6135e-01, -3.4736e-02, -1.0616e-02, -4.0218e-01, -1.4023e+00,
#           4.5802e-01, -6.8231e-01,  1.6740e+00,  1.3828e+00, -3.9328e-01],
#         [ 1.6013e+00,  3.5756e-01,  5.8061e-02, -1.0706e+00,  8.0817e-01,
#          -1.5792e+00,  6.2062e-01, -1.1529e+00, -1.8664e-02, -1.5056e+00],
#         [-2.0841e-01,  1.9413e+00, -1.8736e-01, -1.7040e+00, -2.1154e+00,
#           9.9161e-01,  1.4112e+00, -9.0756e-01,  4.2067e-03, -1.4650e+00],
#         [ 6.0858e-01, -7.5762e-02, -4.1397e-01, -1.3813e+00,  1.4039e+00,
#           2.2193e+00,  4.9856e-01, -1.6332e+00,  3.4909e-02,  5.7698e-01],
#         [-9.5156e-03, -4.0038e-01, -7.7290e-01, -3.9625e-01,  5.6476e-01,
#           3.0277e-01, -1.5120e-01, -4.7413e-01,  6.3175e-01, -2.2864e-01],
#         [ 2.0871e-01, -1.4548e+00,  2.3239e-01, -2.6004e-01,  1.0477e+00,
#           5.4506e-01,  1.7255e+00,  5.4060e-01,  6.8453e-02,  3.2986e-01],
#         [ 1.2613e+00,  8.7723e-01, -2.2911e+00,  1.8940e+00, -2.3214e+00,
#          -6.4234e-01, -8.5402e-01, -6.6815e-02, -7.9470e-01,  7.8126e-01],
#         [ 1.9472e+00,  2.1232e-01, -2.7720e-01,  1.2925e+00,  1.3788e+00,
#           8.8038e-02, -2.0366e-01,  4.0682e-01, -1.6067e-01,  2.7960e-01],
#         [-4.4193e-01,  1.0320e-02, -1.8799e+00,  1.3125e+00,  1.1692e+00,
#          -3.6367e-01, -4.4938e-01,  1.2848e+00, -6.1986e-01, -7.9394e-01],
#         [ 3.0511e-01,  7.2426e-01, -8.7868e-02, -1.1320e+00,  2.2651e-01,
#           5.2910e-01,  1.5444e+00, -3.5117e-01,  1.4816e-01, -1.1293e+00],
#         [ 1.3774e+00, -1.6838e-01, -2.7773e+00,  3.0255e-01,  7.5064e-01,
#          -6.4097e-01, -2.0733e+00,  6.5992e-01,  1.7670e+00, -1.1698e+00],
#         [-1.3174e-01, -6.0044e-01, -1.4066e+00, -2.8835e-01, -1.0946e+00,
#          -8.6581e-01,  8.3675e-01, -9.4010e-01,  1.4285e+00,  1.9833e-01],
#         [-2.3386e+00, -1.5901e+00,  8.4838e-01, -9.3910e-02, -1.3151e-01,
#          -3.5333e-02,  4.6863e-03,  1.5220e-01, -1.4526e+00,  1.2706e+00],
#         [ 1.0898e+00, -4.8068e-01, -6.3005e-01,  1.1918e+00, -1.0329e+00,
#           3.8321e-01, -2.7745e+00, -2.0164e-01, -5.5342e-01,  3.3749e-01],
#         [ 9.7845e-01,  1.1227e+00,  5.8513e-01,  1.3818e+00, -8.1578e-01,
#           1.2409e+00,  1.7996e+00,  1.6228e+00,  2.4195e-01,  7.3594e-01],
#         [ 1.3792e+00, -1.9271e-01, -5.9315e-01,  3.8337e-01,  3.2405e-01,
#           5.8950e-01,  7.8884e-01, -9.3753e-01, -1.4469e-01, -9.7424e-01],
#         [ 6.2296e-01, -3.4590e-01, -6.7492e-01, -1.2533e+00, -4.9027e-01,
#           9.4008e-02,  8.5306e-01, -1.0445e-02,  1.1147e+00, -1.1784e+00],
#         [-1.0688e+00,  3.8018e-01,  1.5242e-01,  6.2388e-02,  4.0209e-01,
#           1.6429e+00, -4.0248e-01, -6.9266e-01, -1.2716e-01,  8.2830e-01],
#         [ 3.6750e-01, -1.6424e+00,  1.6907e+00, -1.8850e+00, -7.8599e-01,
#          -1.2742e+00,  1.1044e+00,  1.1176e+00, -8.6887e-01, -1.5557e+00],
#         [ 4.5628e-01,  2.6207e-01,  5.0241e-01, -4.7595e-01, -1.5218e+00,
#          -1.2173e+00,  1.3267e+00,  6.5520e-01,  6.8604e-01, -6.8316e-01],
#         [ 8.9299e-01,  1.6673e+00,  1.7872e+00, -1.3676e+00, -8.0266e-01,
#           4.5739e-01, -1.0744e-01,  2.1310e+00,  2.4406e-01,  1.0901e+00],
#         [-1.2988e+00, -2.6964e-01,  2.0650e-01, -3.8393e-01, -5.7276e-01,
#          -3.6839e-01, -1.6833e-01,  2.0470e+00, -1.2073e+00,  7.8534e-01],
#         [ 8.2412e-02,  1.6416e+00, -5.6889e-01,  3.4890e-01, -1.1777e+00,
#           9.8450e-01,  1.3597e+00,  1.4742e+00, -5.5363e-01, -1.5111e-02],
#         [ 4.7541e-01,  5.7430e-01,  1.9246e-01,  4.3041e-01, -4.3685e-01,
#          -7.7793e-01,  1.2181e+00, -1.5328e-01,  3.9226e-01, -2.4747e-01],
#         [-2.6899e-01,  1.3260e-01,  8.0848e-02,  4.5395e-01, -1.3718e+00,
#          -4.7459e-01, -9.6763e-01, -6.9899e-01, -9.2018e-02, -9.8115e-01],
#         [-5.3460e-01, -1.3062e+00, -9.2463e-01,  6.2142e-01,  1.7852e-01,
#           2.8669e-01,  3.5793e-01, -1.0362e+00, -3.3705e-01,  1.0512e+00],
#         [-1.3510e+00,  5.4095e-01,  1.1344e+00, -4.2129e-01,  3.0239e-02,
#          -5.5710e-01, -1.0027e+00,  1.2805e+00,  1.2131e+00,  1.2110e-01],
#         [-1.2744e+00,  8.8456e-01, -7.5566e-01,  2.0247e+00,  1.8218e+00,
#           1.5864e+00,  8.6552e-01, -2.7655e-01, -1.9468e-01, -3.4295e-02],
#         [-5.6552e-01,  4.3978e-01, -1.0542e+00, -2.3126e+00, -9.0273e-01,
#          -1.4186e+00,  3.7751e-01, -2.0932e-01,  1.7607e+00, -5.6119e-01],
#         [-9.1843e-01,  9.8460e-01, -1.5836e+00, -2.9579e-01,  3.5080e-01,
#           6.3477e-01, -7.4758e-01, -2.1754e-01, -1.5073e+00, -7.4246e-01],
#         [ 4.5582e-01, -4.7636e-01,  8.9321e-01,  4.7491e-01,  8.5692e-01,
#          -7.3647e-01,  7.2728e-01,  1.3461e-01,  2.0774e+00, -8.7831e-01],
#         [ 8.6748e-02, -1.2705e+00, -1.9873e-01, -4.1027e-01, -8.7691e-01,
#          -1.5859e-02,  1.6088e+00, -4.2978e-01, -7.7904e-01,  1.1783e+00],
#         [ 4.2371e-02, -6.1082e-01, -4.4424e-01,  2.9269e-01,  2.5777e-01,
#          -2.1504e+00, -2.1542e+00, -4.2973e-01,  1.4808e+00, -2.7136e+00],
#         [-6.3514e-01, -9.3221e-01, -1.1812e+00,  2.9110e-01, -1.9089e+00,
#          -6.1621e-02, -6.2887e-01, -3.9982e-02,  6.4129e-01, -2.7082e-01],
#         [ 1.3201e+00,  1.9129e-02,  6.4398e-01, -1.6229e+00,  2.4068e-01,
#           1.6771e+00, -1.2024e+00, -5.7697e-01,  2.2181e-01, -9.7382e-02],
#         [-3.6622e-01,  5.1108e-01,  9.4761e-01, -1.7694e+00, -7.0185e-02,
#          -1.2068e+00, -9.1919e-01,  4.7819e-01,  6.2740e-01, -9.0721e-01],
#         [-1.1753e+00, -1.6300e+00, -1.1510e-01,  1.3117e+00, -2.6502e-01,
#           1.5695e+00, -9.7817e-01,  4.6866e-01, -3.3286e-02, -8.6844e-01],
#         [-4.7744e-01, -1.1587e+00,  3.3356e-01, -5.5534e-01,  8.2570e-01,
#           1.3953e+00,  1.5590e-01, -1.7197e-01, -1.0173e+00, -1.6461e+00],
#         [-4.5704e-01, -8.8567e-01,  3.7435e-02, -1.0223e+00, -6.0164e-01,
#          -3.4738e-01,  1.5541e-01,  9.4392e-03, -5.4451e-01,  3.1811e-01],
#         [-8.7211e-02,  1.9312e+00,  8.2432e-01,  3.2105e-01, -3.4807e-01,
#          -9.6609e-01, -6.5453e-01, -2.0421e+00,  9.9742e-01,  3.8142e-01],
#         [ 1.1022e+00,  1.4521e-01, -1.2878e+00,  1.9194e+00, -9.3162e-01,
#          -3.8786e-01,  1.8630e+00,  6.3446e-01,  8.0740e-02,  7.6934e-01],
#         [ 1.3547e+00,  1.1477e+00, -1.1455e+00,  3.3045e-01, -9.9611e-01,
#           6.8377e-02,  1.1345e+00, -6.2708e-01,  4.5413e-01, -4.4132e-01],
#         [ 1.6922e+00, -1.2364e-01,  5.8005e-01, -3.1850e-01, -3.3317e-01,
#           1.3781e+00,  6.8129e-01, -3.4172e-01,  3.4814e-01,  9.9297e-01],
#         [ 6.1818e-01,  2.5706e+00, -6.1464e-01, -4.2742e-01,  7.9914e-01,
#           3.4314e-01, -7.1088e-01,  4.0654e-01,  9.5622e-01,  3.0749e-01],
#         [ 3.1811e-01, -1.8298e+00,  1.8508e+00, -1.2886e+00,  1.2673e+00,
#          -9.6881e-01, -4.6094e-01,  8.4074e-01, -1.9394e-01, -1.4038e-01]])

# %%
mean = tensor.mean()
mean
# Out:
# tensor(0.0152)

# %%
std = tensor.std()
std
# Out:
# tensor(0.9839)

# %%
normalized_tensor = (tensor - mean) / std
print(normalized_tensor)
# Out:
# tensor([[-1.2746e+00, -1.2160e+00, -1.2032e-01,  1.6928e+00, -3.1114e-01,
#          -2.0894e-01, -4.6237e-01,  8.8927e-01,  4.4262e-01,  8.1847e-01],
#         [-7.7609e-01,  6.7569e-01, -1.6290e-01, -2.5981e-02, -5.0393e-01,
#          -3.2271e-02, -6.2531e-01, -6.2054e-01, -4.5499e-01, -7.3971e-01],
#         [-7.2721e-01,  1.2360e+00,  9.1730e-01, -1.0213e-01, -1.7575e+00,
#           3.7896e-01, -6.3090e-02, -6.9338e-01,  2.7699e-01, -8.8366e-01],
#         [ 7.4685e-01, -2.2052e+00, -2.0373e-01, -3.6462e-01, -1.0143e+00,
#           1.4811e+00,  5.1148e-01,  1.1375e+00, -1.1382e+00,  3.9081e-01],
#         [ 5.9920e-01,  8.5688e-02,  2.0485e-01, -7.7227e-01, -1.9358e+00,
#           8.2101e-01, -3.0036e-02,  1.0590e+00, -1.0694e+00, -3.1789e-01],
#         [-8.8112e-01,  2.7847e-01, -9.2331e-01,  1.8798e+00,  3.6102e-02,
#           4.5376e-03, -1.4529e-01,  3.4818e-01, -1.1577e+00,  4.5777e-01],
#         [-3.1164e+00,  8.4927e-01,  5.7389e-01,  2.3148e-01, -1.4181e+00,
#          -3.8549e-01, -2.1704e-01,  5.4830e-01,  2.5426e-01, -2.9030e-01],
#         [ 1.2145e+00, -8.8558e-01,  8.9633e-01,  1.0989e+00, -1.1602e-02,
#           4.0982e-01,  7.4188e-01,  4.2826e-03, -4.6535e-01,  1.2436e+00],
#         [ 1.4031e+00, -2.4353e-02,  3.0395e-02,  2.0617e-01,  2.1969e+00,
#           2.2134e+00, -6.6937e-01,  1.6936e+00, -9.2863e-01, -8.7937e-01],
#         [-9.8619e-01,  1.8238e-02,  4.0896e-01,  1.9804e+00, -9.9601e-01,
#           7.5636e-01, -3.3870e-01,  5.5963e-01,  2.4393e-01, -1.1363e+00],
#         [ 8.2192e-01, -1.1810e-02, -1.7701e+00,  2.1884e-01,  3.7914e-01,
#          -5.4914e-01, -1.3894e-01,  4.0699e-01,  1.0106e+00,  6.7753e-01],
#         [-7.5741e-01, -8.5941e-01, -1.6134e+00,  6.4031e-01,  1.6296e-01,
#           2.8827e-01, -6.2707e-01,  1.1118e+00, -2.8958e-01, -4.6056e-01],
#         [-5.6473e-01,  4.8098e-01,  1.4392e-01,  1.8688e-01,  6.8261e-01,
#          -4.4846e-01, -7.8384e-01,  1.5848e-01, -1.1775e+00, -6.6064e-01],
#         [ 1.1842e+00,  3.6598e-01,  1.5130e-01, -6.0699e-01, -6.3316e-01,
#          -2.2335e-01,  7.3139e-01,  1.4216e+00, -8.5738e-02, -2.6974e-01],
#         [-6.5772e-01, -1.2076e-01,  9.8391e-01, -2.3008e-01, -4.0550e-01,
#          -7.9616e-01, -1.0353e+00, -9.9679e-01,  1.9910e-01, -1.4525e+00],
#         [ 8.9122e-01, -3.2440e-01, -4.5667e-01,  2.8230e-01,  1.0193e-01,
#          -1.9719e-01, -1.1103e-01, -6.5881e-01,  2.0323e+00,  6.3959e-01],
#         [-1.0819e+00,  1.0852e+00, -9.3595e-01, -1.0726e+00,  3.6949e-01,
#          -1.9736e-01, -7.0170e-01, -7.7940e-01, -1.3116e+00, -1.0122e+00],
#         [ 7.7532e-01, -2.5728e-01, -7.9321e-01, -8.9375e-01, -3.0855e-01,
#          -1.1192e+00,  4.3129e-02,  3.4242e-01,  1.0993e+00, -1.0199e+00],
#         [ 2.0170e+00, -1.3365e+00, -9.3265e-01, -2.4749e+00,  1.2250e+00,
#          -1.7141e-01, -5.3577e-01,  1.0575e-01,  1.4368e+00,  2.1057e+00],
#         [ 1.0081e+00, -1.4319e-01, -3.1663e-01,  6.2301e-01,  7.9482e-01,
#           6.9169e-01, -2.0367e-01,  1.8691e-01,  1.9173e-01, -7.5213e-01],
#         [-1.0513e-01, -1.2187e+00, -2.5431e-01,  6.6357e-01, -7.4780e-01,
#           9.8224e-01,  1.6359e-01,  8.7125e-02,  5.1138e-01,  9.2692e-02],
#         [-8.7414e-02,  1.7445e-01, -1.1697e+00, -6.3763e-01,  4.6555e-01,
#           2.1170e-01,  4.5125e-01,  3.5450e-01,  2.3670e-01, -5.9622e-01],
#         [-1.9293e+00,  1.6370e+00, -7.3077e-01,  5.5183e-01,  4.1218e-01,
#           1.2985e+00, -7.8502e-02, -9.1134e-02,  1.8287e+00,  4.0391e-01],
#         [-5.6271e-01, -6.9632e-01,  1.1884e-01, -4.7837e-01,  7.0621e-01,
#          -1.4708e+00,  1.3676e+00,  6.5996e-01, -2.1277e-01, -1.4098e+00],
#         [ 1.7824e+00,  1.2347e+00,  2.8509e-01,  8.3839e-01, -1.2800e+00,
#          -7.3685e-01,  1.1609e+00,  2.5904e-02,  1.1183e+00, -1.9151e+00],
#         [ 1.0919e+00, -6.8862e-01, -4.6957e-01, -7.0834e-01, -3.6170e-01,
#           2.1635e-01, -1.0265e+00, -1.3634e+00, -1.4891e+00,  1.2940e-01],
#         [ 3.1037e-01, -6.1026e-01,  3.9730e-01,  2.4607e-01,  3.1172e-01,
#           1.1896e-01,  3.3695e-01, -9.8374e-02, -1.5098e+00, -3.6262e-01],
#         [ 1.2306e+00,  1.9070e+00, -2.0609e+00, -5.4016e-01,  1.7478e+00,
#           1.7111e-02,  9.7318e-01,  1.0904e+00, -1.1418e+00,  2.1665e+00],
#         [-7.4903e-01,  1.9294e+00, -3.4806e-01,  4.7449e-01, -1.9053e+00,
#           1.2817e-01,  1.6936e+00,  9.1372e-01, -5.6498e-01, -8.5897e-01],
#         [ 1.8746e-01, -2.1200e-01, -1.2551e+00,  1.0428e+00, -1.2351e-01,
#           5.9120e-02,  5.8825e-01,  1.3493e+00, -5.3948e-01,  3.1009e-01],
#         [ 1.5623e+00,  1.3590e+00,  1.1669e+00, -5.8482e-01, -1.6898e-01,
#          -5.5791e-01,  5.5578e-01, -2.8344e+00,  1.1603e+00, -2.6829e-01],
#         [-1.2719e-01, -4.4564e-01, -1.8980e+00, -1.2246e+00, -6.8443e-01,
#           3.8627e-01, -7.2535e-01,  8.1747e-01,  8.8165e-01,  9.7268e-01],
#         [-1.4414e-01, -6.1368e-02,  1.6816e-01,  5.2832e-01, -1.1285e+00,
#           2.2158e-01,  5.7851e-01, -2.3392e+00,  2.0428e-01, -6.3777e-01],
#         [-2.7423e-01,  9.9341e-01,  4.4571e-01, -9.6369e-01, -7.2796e-02,
#           9.5704e-01,  1.9833e+00,  4.3224e-01, -6.1952e-01,  7.1700e-01],
#         [-1.1210e+00, -2.1012e-01,  8.1401e-01, -8.5227e-01, -3.3385e-01,
#          -2.0173e-01, -1.9673e-01,  2.0977e+00,  1.3587e-01,  3.2278e+00],
#         [-9.6417e-01, -1.3809e-01, -8.8631e-01, -1.5087e+00,  9.2580e-01,
#          -5.8405e-01,  2.2390e+00,  3.9113e-01,  4.1356e-01, -1.3042e+00],
#         [-1.0934e+00,  1.0471e+00,  1.1582e+00,  3.1107e-01,  1.2324e-01,
#          -1.8141e+00, -5.2014e-01,  1.6236e+00,  1.9578e-02,  5.0180e-01],
#         [ 6.4217e-01, -5.2565e-01, -1.6133e-01, -1.2591e+00, -1.6266e+00,
#           1.1097e+00,  2.5998e+00, -7.3216e-01, -1.1935e+00, -2.9694e-01],
#         [ 1.1357e+00, -9.9287e-01, -2.8979e-02, -3.2856e-01, -1.3434e+00,
#           1.1087e+00,  9.2120e-01, -1.4349e+00, -9.1800e-01, -2.2628e+00],
#         [ 1.6822e+00,  4.5079e-02, -1.5396e-02,  5.6266e-01,  8.2185e-01,
#          -1.0084e+00, -7.8492e-01,  6.1847e-01, -2.8179e-01,  4.9991e-01],
#         [ 5.8195e-01, -7.9470e-01,  1.3045e-01, -9.3817e-01,  2.2107e+00,
#           2.4543e-01,  4.5467e-01, -1.1752e+00, -6.0879e-01, -7.3512e-01],
#         [-1.2085e+00, -6.5784e-01, -1.1297e+00, -8.1302e-01, -6.0010e-01,
#           5.0684e-01, -4.4338e-01, -6.9001e-01,  1.4684e+00, -1.9795e+00],
#         [ 2.8446e-01,  1.9696e+00,  4.7838e-02, -1.1415e+00, -6.8119e-02,
#           4.0282e-01, -3.1696e-01, -2.8512e-01, -8.2830e-01,  1.0435e+00],
#         [ 1.3069e+00, -4.3060e-01,  8.6633e-01,  1.5786e+00,  1.7096e-01,
#          -7.4540e-02,  3.1183e-01,  4.5910e-01, -7.9474e-04, -1.2181e+00],
#         [ 1.9756e+00, -4.9142e-01,  1.3388e+00, -1.1005e-01, -1.1834e+00,
#           3.8412e-01, -4.1109e-01,  5.2257e-01, -1.0621e-01, -2.9004e+00],
#         [ 4.4757e-01, -2.9455e-01,  9.4958e-01, -9.0181e-01,  8.0068e-01,
#           2.6654e-01,  1.6970e+00,  4.3569e-01, -7.1134e-01, -7.9693e-01],
#         [ 1.9263e+00, -9.5883e-01,  7.3928e-01,  2.0557e+00, -1.3141e+00,
#           4.1262e-01, -7.5627e-01, -9.7590e-01,  6.4363e-01, -3.6973e-01],
#         [ 4.3743e-01,  1.2301e-03, -1.3843e+00,  8.5674e-01, -1.9628e-01,
#           7.9789e-01,  1.2402e+00,  5.3934e-01,  3.8714e-01,  1.6498e-01],
#         [ 9.9943e-01,  2.1904e-02,  2.1810e-01, -2.0325e+00, -1.2871e+00,
#           6.1668e-01,  6.5348e-01,  1.5180e+00,  5.6654e-01,  3.7723e-01],
#         [ 2.6125e-01,  4.5343e-01,  1.2258e-01,  5.0982e-01, -9.7307e-01,
#           1.3544e+00,  1.7653e+00, -3.9597e-01,  9.5093e-01,  1.3132e+00],
#         [-7.7901e-01, -1.0220e-02,  5.7272e-01, -1.1332e+00,  1.9507e+00,
#          -4.6839e-01, -4.9798e-01, -3.2302e-01, -3.1420e-01,  2.5616e+00],
#         [-6.7603e-02, -2.8242e-01, -4.4519e-01, -7.5970e-01, -4.1990e-01,
#          -2.0509e-02, -2.2169e+00,  5.2375e-01, -4.7606e-01,  1.2490e+00],
#         [ 1.8765e+00, -1.3322e-01, -7.0887e-01,  4.1275e-01, -1.3597e+00,
#           1.2159e+00, -3.3422e-01,  1.2199e-01, -1.2435e+00,  3.2050e+00],
#         [ 2.3197e+00, -1.5906e-01, -2.0435e+00,  2.0450e-02, -6.4030e-01,
#           1.4842e+00, -5.4703e-01, -1.2285e+00, -1.1229e+00,  1.5172e+00],
#         [ 2.4794e-01,  2.9573e+00, -1.3308e+00,  1.3111e-01,  1.5124e+00,
#           8.5860e-01,  5.6019e-01, -1.4255e+00, -3.5710e-01,  2.0501e-01],
#         [-7.8926e-01, -5.0749e-02, -2.6234e-02, -4.2421e-01, -1.4407e+00,
#           4.5008e-01, -7.0893e-01,  1.6860e+00,  1.3900e+00, -4.1517e-01],
#         [ 1.6121e+00,  3.4797e-01,  4.3569e-02, -1.1036e+00,  8.0596e-01,
#          -1.6205e+00,  6.1534e-01, -1.1872e+00, -3.4414e-02, -1.5457e+00],
#         [-2.2727e-01,  1.9576e+00, -2.0588e-01, -1.7474e+00, -2.1655e+00,
#           9.9241e-01,  1.4189e+00, -9.3787e-01, -1.1168e-02, -1.5045e+00],
#         [ 6.0310e-01, -9.2446e-02, -4.3619e-01, -1.4194e+00,  1.4115e+00,
#           2.2402e+00,  4.9128e-01, -1.6754e+00,  2.0037e-02,  5.7099e-01],
#         [-2.5115e-02, -4.2238e-01, -8.0100e-01, -4.1819e-01,  5.5856e-01,
#           2.9228e-01, -1.6912e-01, -4.9734e-01,  6.2665e-01, -2.4783e-01],
#         [ 1.9668e-01, -1.4941e+00,  2.2076e-01, -2.7974e-01,  1.0494e+00,
#           5.3854e-01,  1.7384e+00,  5.3401e-01,  5.4130e-02,  3.1982e-01],
#         [ 1.2665e+00,  8.7615e-01, -2.3441e+00,  1.9095e+00, -2.3749e+00,
#          -6.6831e-01, -8.8346e-01, -8.3353e-02, -8.2316e-01,  7.7861e-01],
#         [ 1.9637e+00,  2.0035e-01, -2.9719e-01,  1.2983e+00,  1.3859e+00,
#           7.4036e-02, -2.2244e-01,  3.9803e-01, -1.7875e-01,  2.6873e-01],
#         [-4.6461e-01, -4.9544e-03, -1.9261e+00,  1.3186e+00,  1.1729e+00,
#          -3.8507e-01, -4.7219e-01,  1.2904e+00, -6.4545e-01, -8.2239e-01],
#         [ 2.9467e-01,  7.2068e-01, -1.0475e-01, -1.1660e+00,  2.1477e-01,
#           5.2233e-01,  1.5542e+00, -3.7237e-01,  1.3514e-01, -1.1632e+00],
#         [ 1.3846e+00, -1.8658e-01, -2.8383e+00,  2.9206e-01,  7.4749e-01,
#          -6.6692e-01, -2.1227e+00,  6.5529e-01,  1.7805e+00, -1.2044e+00],
#         [-1.4934e-01, -6.2572e-01, -1.4451e+00, -3.0851e-01, -1.1280e+00,
#          -8.9544e-01,  8.3501e-01, -9.7094e-01,  1.4365e+00,  1.8613e-01],
#         [-2.3924e+00, -1.6315e+00,  8.4683e-01, -1.1089e-01, -1.4911e-01,
#          -5.1355e-02, -1.0681e-02,  1.3925e-01, -1.4918e+00,  1.2760e+00],
#         [ 1.0922e+00, -5.0400e-01, -6.5581e-01,  1.1958e+00, -1.0652e+00,
#           3.7404e-01, -2.8354e+00, -2.2038e-01, -5.7793e-01,  3.2758e-01],
#         [ 9.7903e-01,  1.1257e+00,  5.7927e-01,  1.3889e+00, -8.4459e-01,
#           1.2458e+00,  1.8136e+00,  1.6340e+00,  2.3047e-01,  7.3255e-01],
#         [ 1.3864e+00, -2.1131e-01, -6.1831e-01,  3.7421e-01,  3.1391e-01,
#           5.8371e-01,  7.8632e-01, -9.6833e-01, -1.6250e-01, -1.0056e+00],
#         [ 6.1772e-01, -3.6701e-01, -7.0142e-01, -1.2893e+00, -5.1375e-01,
#           8.0104e-02,  8.5158e-01, -2.6059e-02,  1.1175e+00, -1.2132e+00],
#         [-1.1017e+00,  3.7096e-01,  1.3948e-01,  4.7966e-02,  3.9323e-01,
#           1.6543e+00, -4.2451e-01, -7.1945e-01, -1.4469e-01,  8.2642e-01],
#         [ 3.5808e-01, -1.6848e+00,  1.7029e+00, -1.9313e+00, -8.1431e-01,
#          -1.3105e+00,  1.1070e+00,  1.1204e+00, -8.9854e-01, -1.5966e+00],
#         [ 4.4831e-01,  2.5092e-01,  4.9520e-01, -4.9919e-01, -1.5622e+00,
#          -1.2527e+00,  1.3330e+00,  6.5049e-01,  6.8183e-01, -7.0980e-01],
#         [ 8.9217e-01,  1.6792e+00,  1.8010e+00, -1.4055e+00, -8.3125e-01,
#           4.4944e-01, -1.2464e-01,  2.1504e+00,  2.3261e-01,  1.0925e+00],
#         [-1.3355e+00, -2.8950e-01,  1.9444e-01, -4.0567e-01, -5.9758e-01,
#          -3.8986e-01, -1.8653e-01,  2.0651e+00, -1.2425e+00,  7.8276e-01],
#         [ 6.8319e-02,  1.6531e+00, -5.9365e-01,  3.3917e-01, -1.2124e+00,
#           9.8519e-01,  1.3666e+00,  1.4829e+00, -5.7814e-01, -3.0802e-02],
#         [ 4.6775e-01,  5.6827e-01,  1.8017e-01,  4.2202e-01, -4.5944e-01,
#          -8.0611e-01,  1.2226e+00, -1.7123e-01,  3.8325e-01, -2.6697e-01],
#         [-2.8884e-01,  1.1933e-01,  6.6728e-02,  4.4595e-01, -1.4097e+00,
#          -4.9781e-01, -9.9892e-01, -7.2589e-01, -1.0897e-01, -1.0127e+00],
#         [-5.5881e-01, -1.3430e+00, -9.5522e-01,  6.1615e-01,  1.6600e-01,
#           2.7594e-01,  3.4835e-01, -1.0686e+00, -3.5801e-01,  1.0530e+00],
#         [-1.3885e+00,  5.3436e-01,  1.1376e+00, -4.4363e-01,  1.5290e-02,
#          -5.8167e-01, -1.0346e+00,  1.2861e+00,  1.2175e+00,  1.0764e-01],
#         [-1.3107e+00,  8.8361e-01, -7.8348e-01,  2.0424e+00,  1.8362e+00,
#           1.5969e+00,  8.6425e-01, -2.9652e-01, -2.1331e-01, -5.0301e-02],
#         [-5.9023e-01,  4.3154e-01, -1.0869e+00, -2.3659e+00, -9.3296e-01,
#          -1.4573e+00,  3.6825e-01, -2.2819e-01,  1.7741e+00, -5.8582e-01],
#         [-9.4892e-01,  9.8528e-01, -1.6250e+00, -3.1607e-01,  3.4110e-01,
#           6.2972e-01, -7.7527e-01, -2.3655e-01, -1.5475e+00, -7.7007e-01],
#         [ 4.4784e-01, -4.9961e-01,  8.9239e-01,  4.6724e-01,  8.5551e-01,
#          -7.6398e-01,  7.2375e-01,  1.2137e-01,  2.0960e+00, -9.0814e-01],
#         [ 7.2725e-02, -1.3068e+00, -2.1743e-01, -4.3243e-01, -9.0672e-01,
#          -3.1563e-02,  1.6197e+00, -4.5226e-01, -8.0724e-01,  1.1822e+00],
#         [ 2.7621e-02, -6.3627e-01, -4.6696e-01,  2.8204e-01,  2.4654e-01,
#          -2.2011e+00, -2.2049e+00, -4.5221e-01,  1.4896e+00, -2.7734e+00],
#         [-6.6099e-01, -9.6292e-01, -1.2160e+00,  2.8043e-01, -1.9556e+00,
#          -7.8075e-02, -6.5461e-01, -5.6081e-02,  6.3635e-01, -2.9070e-01],
#         [ 1.3263e+00,  3.9986e-03,  6.3908e-01, -1.6649e+00,  2.2917e-01,
#           1.6891e+00, -1.2375e+00, -6.0187e-01,  2.1000e-01, -1.1442e-01],
#         [-3.8767e-01,  5.0401e-01,  9.4769e-01, -1.8138e+00, -8.6778e-02,
#          -1.2420e+00, -9.4969e-01,  4.7058e-01,  6.2223e-01, -9.3751e-01],
#         [-1.2100e+00, -1.6722e+00, -1.3243e-01,  1.3177e+00, -2.8480e-01,
#           1.5798e+00, -1.0096e+00,  4.6089e-01, -4.9275e-02, -8.9810e-01],
#         [-5.0070e-01, -1.1931e+00,  3.2358e-01, -5.7988e-01,  8.2378e-01,
#           1.4027e+00,  1.4301e-01, -1.9023e-01, -1.0494e+00, -1.6885e+00],
#         [-4.7997e-01, -9.1562e-01,  2.2605e-02, -1.0545e+00, -6.2694e-01,
#          -3.6852e-01,  1.4252e-01, -5.8499e-03, -5.6887e-01,  3.0788e-01],
#         [-1.0408e-01,  1.9474e+00,  8.2238e-01,  3.1087e-01, -3.6922e-01,
#          -9.9736e-01, -6.8070e-01, -2.0910e+00,  9.9831e-01,  3.7222e-01],
#         [ 1.1048e+00,  1.3215e-01, -1.3243e+00,  1.9354e+00, -9.6232e-01,
#          -4.0965e-01,  1.8781e+00,  6.2941e-01,  6.6619e-02,  7.6650e-01],
#         [ 1.3615e+00,  1.1511e+00, -1.1797e+00,  3.2041e-01, -1.0279e+00,
#           5.4053e-02,  1.1376e+00, -6.5280e-01,  4.4613e-01, -4.6399e-01],
#         [ 1.7045e+00, -1.4111e-01,  5.7411e-01, -3.3916e-01, -3.5407e-01,
#           1.3853e+00,  6.7700e-01, -3.6276e-01,  3.3840e-01,  9.9379e-01],
#         [ 6.1286e-01,  2.5972e+00, -6.4015e-01, -4.4987e-01,  7.9678e-01,
#           3.3332e-01, -7.3797e-01,  3.9776e-01,  9.5644e-01,  2.9708e-01],
#         [ 3.0788e-01, -1.8752e+00,  1.8657e+00, -1.3252e+00,  1.2727e+00,
#          -1.0001e+00, -4.8393e-01,  8.3907e-01, -2.1256e-01, -1.5812e-01]])

# %%
normalized_tensor.mean()
# Out:
# tensor(-1.2398e-08)

# %%
normalized_tensor.std()
# Out:
# tensor(1.)

# %% [markdown]
# **Exercise 3: Find the indices of the top 3 values in a tensor**

# %%
tensor = torch.randn(10)
print(tensor)
# Out:
# tensor([-2.7704,  1.9610, -0.7328,  0.0113,  0.4797, -0.0365,  1.0878, -0.0177,
#         -0.5193,  0.8134])

# %% [markdown]
# ***Top 3 maximum values***

# %%
values, indices = torch.topk(tensor, k=3)
values, indices
# Out:
# (tensor([1.9610, 1.0878, 0.8134]), tensor([1, 6, 9]))

# %% [markdown]
# ***Top 3 minimum values***

# %%
values, indices = torch.topk(tensor, k=3, largest=False)
values, indices
# Out:
# (tensor([-2.7704, -0.7328, -0.5193]), tensor([0, 2, 8]))

# %% [markdown]
# **Exercise 4: Implement softmax function**

# %%
logits = torch.randn(2, 5)
print(logits)
# Out:
# tensor([[-1.3440, -1.3025, -0.0280, -0.4115,  0.8032],
#         [-0.9688,  0.1715, -0.5394, -0.9222, -0.7265]])

# %%
exp = torch.exp(logits)
print(exp)
# Out:
# tensor([[0.2608, 0.2718, 0.9724, 0.6627, 2.2327],
#         [0.3796, 1.1871, 0.5831, 0.3977, 0.4836]])

# %%
sum_exp = sum(exp)
sum_exp
# Out:
# tensor([0.6403, 1.4589, 1.5555, 1.0603, 2.7163])

# %%
softmax = exp / sum_exp
print(softmax)
# Out:
# tensor([[0.4073, 0.1863, 0.6251, 0.6250, 0.8220],
#         [0.5927, 0.8137, 0.3749, 0.3750, 0.1780]])

# %%
## Another way
softmax_another_way = torch.softmax(logits, dim=0)
print(softmax_another_way)
# Out:
# tensor([[0.4073, 0.1863, 0.6251, 0.6250, 0.8220],
#         [0.5927, 0.8137, 0.3749, 0.3750, 0.1780]])

# %% [markdown]
# **Exercise 5: Compute cosine similarity between two vectors**

# %%
v1 = torch.randn(100)
v2 = torch.randn(100)

# %%
v1_dot_v2 = v1 @ v2

# %%
norm_v1_mul_v2 = torch.sqrt(v1 @ v1) * torch.sqrt(v2 @ v2)
norm_v1_mul_v2
# Out:
# tensor(100.9333)

# %%
cosine_similarity = v1_dot_v2 / norm_v1_mul_v2
cosine_similarity
# Out:
# tensor(0.0615)

# %%
## Another way
cosine_similarity_another_way = torch.dot(v1, v2) / (torch.norm(v1) * torch.norm(v2))
cosine_similarity_another_way
# Out:
# tensor(0.0615)

# %%
cosine_similarity_another_way_available = torch.cosine_similarity(v1, v2, dim=0)
cosine_similarity_another_way_available
# Out:
# tensor(0.0615)
